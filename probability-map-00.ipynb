# %% [markdown]
# <a href="https://colab.research.google.com/github/sidhu2690/MARL/blob/main/probability_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt


GRID = 12
N_ROBOTS = 12
ADV_FRAC = 0.34
STEPS = 150
EPSILON = 0.05
CONTRA_THRESH = 0.2
SEED = 40

rng = np.random.default_rng(SEED)
torch.manual_seed(SEED)


def make_true_map(grid):
  xs, ys = np.meshgrid(np.arange(grid), np.arange(grid))
  field = np.zeros((grid, grid))
  for _ in range(5):
    cx, cy = rng.uniform(0, grid, 2)
    amp = rng.uniform(0.5, 1.0)
    sigma = rng.uniform(1.5, 3.5)
    field += amp * np.exp(-((xs - cx) ** 2 + (ys - cy) ** 2) / (2 * sigma ** 2))
  field = (field - field.min()) / (field.max() - field.min() + 1e-8)
  return field


def random_walk(grid, steps):
  pos = rng.integers(0, grid, size=2)
  cells = []
  for _ in range(steps):
    while True:
      move = rng.choice([-1, 0, 1], size=2)
      new_pos = np.clip(pos + move, 0, grid - 1)
      if not np.array_equal(new_pos, pos):
        break
    pos = new_pos
    cells.append(tuple(pos))
  return cells


def make_adv_mask(n_robots, adv_frac):
  n_adv = int(n_robots * adv_frac)
  mask = np.array([False] * (n_robots - n_adv) + [True] * n_adv)
  rng.shuffle(mask)
  return mask

def report_value(true_val, adversarial):
  if adversarial:
    val = true_val + rng.choice([-1, 1]) * rng.uniform(0.3, 0.6) + rng.normal(0, 0.1)
  else:
    val = true_val + rng.normal(0, 0.02)
  return float(np.clip(val, 0, 1))

# %%
# Part 1: alpha_net

class AlphaNet(nn.Module):
  def __init__(self):
    super().__init__()
    self.net = nn.Sequential(
      nn.Linear(3, 16), nn.ReLU(),
      nn.Linear(16, 8), nn.ReLU(),
      nn.Linear(8, 1), nn.Sigmoid(),
    )
  def forward(self, feats):
    return self.net(feats).squeeze(-1)



def train_alpha_net(episodes=400, lr=2e-3):
  alpha_net = AlphaNet()
  optimizer = torch.optim.Adam(alpha_net.parameters(), lr=lr)
  loss_history = []
  for ep in range(episodes):
    TRUE_MAP = make_true_map(GRID)
    is_adv = make_adv_mask(N_ROBOTS, ADV_FRAC)
    walks = [random_walk(GRID, STEPS) for _ in range(N_ROBOTS)]
    c = np.zeros(N_ROBOTS)
    D_sum = np.zeros(N_ROBOTS)
    D_n = np.zeros(N_ROBOTS)
    cell_reports = {}
    ep_loss = 0.0
    for t in range(STEPS):
      touched_cells = set()
      for i in range(N_ROBOTS):
        cell = walks[i][t]
        r_i = report_value(TRUE_MAP[cell], is_adv[i])
        others = cell_reports.get(cell, [])
        if others:
          residuals = [abs(r_i - r_j) for _, r_j in others]
          D_sum[i] += float(np.mean(residuals))
          D_n[i] += 1
          for j, r_j in others:
            if abs(r_i - r_j) > CONTRA_THRESH:
              c[i] += 1
              c[j] += 1
        cell_reports.setdefault(cell, []).append((i, r_i))
        touched_cells.add(cell)
      mu_c, sigma_c = c.mean(), c.std()
      z = (c - mu_c) / (sigma_c + EPSILON)
      D = np.divide(D_sum, D_n, out=np.zeros_like(D_sum), where=D_n > 0)
      c_norm = c / (t + 1)
      feats = torch.tensor(np.stack([c_norm, z, D], axis=1), dtype=torch.float32)
      alpha = alpha_net(feats)
      step_loss = 0.0
      for cell in touched_cells:
        reports = cell_reports[cell]
        idx = torch.tensor([r for r, _ in reports])
        vals = torch.tensor([v for _, v in reports], dtype=torch.float32)
        a = alpha[idx]
        M = (a * vals).sum() / (a.sum() + EPSILON)
        step_loss = step_loss + (TRUE_MAP[cell] - M) ** 2
      step_loss = step_loss / len(touched_cells)
      optimizer.zero_grad()
      step_loss.backward()
      optimizer.step()
      ep_loss += step_loss.item()
    loss_history.append(ep_loss / STEPS)
    if (ep + 1) % 100 == 0:
      print(f"[alpha_net] episode {ep+1}/{episodes}  avg loss {loss_history[-1]:.5f}")
  return alpha_net, loss_history

# %%
# Part 2:  Produce (M_t, U_t, N_t) -> Y_t training pairs

PRIOR = 0     # M_t(s) prior for never-observed cells
Y_SCALE = 20.0


def rollout_episode(alpha_net):
  TRUE_MAP = make_true_map(GRID)
  is_adv = make_adv_mask(N_ROBOTS, ADV_FRAC)
  walks = [random_walk(GRID, STEPS) for _ in range(N_ROBOTS)]
  c = np.zeros(N_ROBOTS)
  D_sum = np.zeros(N_ROBOTS)
  D_n = np.zeros(N_ROBOTS)
  cell_reports = {}
  xs, ys = [], []
  for t in range(STEPS):
    for i in range(N_ROBOTS):
      cell = walks[i][t]
      r_i = report_value(TRUE_MAP[cell], is_adv[i])
      others = cell_reports.get(cell, [])
      if others:
        residuals = [abs(r_i - r_j) for _, r_j in others]
        D_sum[i] += float(np.mean(residuals))
        D_n[i] += 1
        for j, r_j in others:
          if abs(r_i - r_j) > CONTRA_THRESH:
            c[i] += 1
            c[j] += 1
      cell_reports.setdefault(cell, []).append((i, r_i))
    mu_c, sigma_c = c.mean(), c.std()
    z = (c - mu_c) / (sigma_c + EPSILON)
    D = np.divide(D_sum, D_n, out=np.zeros_like(D_sum), where=D_n > 0)
    c_norm = c / (t + 1)
    feats = torch.tensor(np.stack([c_norm, z, D], axis=1), dtype=torch.float32)
    with torch.no_grad():
      alpha = alpha_net(feats).numpy()
    W_sum = np.zeros((GRID, GRID))
    A_sum = np.zeros((GRID, GRID))
    N_map = np.zeros((GRID, GRID))
    for cell, reports in cell_reports.items():
      idx = np.array([r for r, _ in reports])
      vals = np.array([v for _, v in reports])
      a = alpha[idx]
      W_sum[cell] = (a * vals).sum()
      A_sum[cell] = a.sum()
      N_map[cell] = len(reports)
    M_t = np.where(A_sum > 0, W_sum / np.maximum(A_sum, 1e-8), PRIOR)
    U_t = A_sum
    N_t = N_map
    err_old = (TRUE_MAP - M_t) ** 2
    r_new = TRUE_MAP.copy()
    M_next = (W_sum + r_new) / (A_sum + 1.0)
    err_new = (TRUE_MAP - M_next) ** 2
    Y_t = np.clip(err_old - err_new, 0, None)
    xs.append(np.stack([M_t, U_t, N_t]).astype(np.float32))
    ys.append(Y_t.astype(np.float32))
  return xs, ys

# %%
# Part 3: g_f -- CNN

class GNet(nn.Module):
  def __init__(self):
    super().__init__()
    self.net = nn.Sequential(
      nn.Conv2d(3, 16, 3, padding=1), nn.ReLU(),
      nn.Conv2d(16, 16, 3, padding=2, dilation=2), nn.ReLU(),
      nn.Conv2d(16, 16, 3, padding=1), nn.ReLU(),
      nn.Conv2d(16, 1, 3, padding=1),
    )
  def forward(self, x):
    return self.net(x).squeeze(1)

def predict_R(gnet, X_t):
  with torch.no_grad():
    raw = gnet(torch.tensor(X_t, dtype=torch.float32).unsqueeze(0)).squeeze(0)
  return (raw / Y_SCALE).numpy()

def build_dataset(alpha_net, episodes):
  X_all, Y_all = [], []
  for ep in range(episodes):
    xs, ys = rollout_episode(alpha_net)
    X_all.extend(xs)
    Y_all.extend(ys)
    if (ep + 1) % 25 == 0:
      print(f"[g_f data] generated {ep+1}/{episodes} episodes "
            f"({len(X_all)} state samples so far)")
  X = torch.tensor(np.stack(X_all), dtype=torch.float32)
  Y = torch.tensor(np.stack(Y_all), dtype=torch.float32) * Y_SCALE
  return X, Y



def train_gnet(X, Y, max_epochs=150, lr=1e-3, batch_size=64,
               patience=8, min_delta=1e-4, balance_visited=True):
  gnet = GNet()
  optimizer = torch.optim.Adam(gnet.parameters(), lr=lr)
  n = X.shape[0]
  loss_history = []
  best_loss = float("inf")
  bad_epochs = 0
  for epoch in range(max_epochs):
    perm = torch.randperm(n)
    epoch_loss = 0.0
    n_batches = 0
    for start in range(0, n, batch_size):
      idx = perm[start:start + batch_size]
      xb, yb = X[idx], Y[idx]
      pred = gnet(xb)
      if balance_visited:
        visited = (xb[:, 2] > 0).float()
        n_vis = visited.sum().clamp(min=1.0)
        n_unvis = (1 - visited).sum().clamp(min=1.0)
        w = visited / n_vis + (1 - visited) / n_unvis
        loss = ((pred - yb) ** 2 * w).sum() / 2.0
      else:
        loss = ((pred - yb) ** 2).mean()
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      epoch_loss += loss.item()
      n_batches += 1
    avg_loss = epoch_loss / n_batches
    loss_history.append(avg_loss)
    print(f"[g_f train] epoch {epoch+1}/{max_epochs}  avg loss {avg_loss:.6f}")
    if best_loss - avg_loss > min_delta:
      best_loss = avg_loss
      bad_epochs = 0
    else:
      bad_epochs += 1
      if bad_epochs >= patience:
        print(f"[g_f train] plateaued at epoch {epoch+1}, stopping early")
        break
  return gnet, loss_history

# %%
# Part 4: validation

def normalize_nonneg(y):
  y = np.clip(y, 0, None)
  s = y.sum()
  if s <= 1e-12:
    return np.full_like(y, 1.0 / y.size)
  return y / s

def kl_divergence(p_true, p_pred, eps=1e-8):
  p_true = np.clip(p_true, eps, None)
  p_pred = np.clip(p_pred, eps, None)
  return float(np.sum(p_true * np.log(p_true / p_pred)))

def topk_overlap(y_true_flat, r_pred_flat, k=5):
  k = min(k, y_true_flat.size)
  true_top = set(np.argsort(y_true_flat)[-k:])
  pred_top = set(np.argsort(r_pred_flat)[-k:])
  return len(true_top & pred_top) / k

def evaluate(gnet, alpha_net, episodes=20, k=5):
  kls, overlaps = [], []
  kls_vis, overlaps_vis = [], []
  kls_unvis, overlaps_unvis = [], []
  sample_X, sample_Y, sample_R = None, None, None
  for ep in range(episodes):
    xs, ys = rollout_episode(alpha_net)
    for X_t, Y_t in zip(xs, ys):
      R_t = predict_R(gnet, X_t)
      N_t = X_t[2]
      p_true = normalize_nonneg(Y_t)
      p_pred = normalize_nonneg(R_t)
      kls.append(kl_divergence(p_true, p_pred))
      overlaps.append(topk_overlap(Y_t.reshape(-1), R_t.reshape(-1), k=k))
      vis_mask = N_t > 0
      if vis_mask.sum() >= k:
        yv, rv = Y_t[vis_mask], R_t[vis_mask]
        kls_vis.append(kl_divergence(normalize_nonneg(yv), normalize_nonneg(rv)))
        overlaps_vis.append(topk_overlap(yv, rv, k=k))
      unvis_mask = N_t == 0
      if unvis_mask.sum() >= k:
        yu, ru = Y_t[unvis_mask], R_t[unvis_mask]
        kls_unvis.append(kl_divergence(normalize_nonneg(yu), normalize_nonneg(ru)))
        overlaps_unvis.append(topk_overlap(yu, ru, k=k))
      if sample_X is None and Y_t.sum() > 1e-6:
        sample_X, sample_Y, sample_R = X_t, Y_t, R_t
  print(f"[g_f eval] FULL GRID   mean KL = {np.mean(kls):.4f}  "
        f"mean top-{k} overlap = {np.mean(overlaps):.3f}")
  print(f"[g_f eval] visited-only    mean KL = {np.mean(kls_vis):.4f}  "
        f"mean top-{k} overlap = {np.mean(overlaps_vis):.3f}  (n={len(kls_vis)})")
  print(f"[g_f eval] unvisited-only  mean KL = {np.mean(kls_unvis):.4f}  "
        f"mean top-{k} overlap = {np.mean(overlaps_unvis):.3f}  (n={len(kls_unvis)})")
  return kls, overlaps, (sample_X, sample_Y, sample_R)



def plot_validation(kls, overlaps, sample, k=5):
  sample_X, sample_Y, sample_R = sample
  p_true = normalize_nonneg(sample_Y)
  p_pred = normalize_nonneg(sample_R)
  fig, axes = plt.subplots(2, 3, figsize=(13, 8))
  axes[0, 0].imshow(sample_X[0], cmap="viridis")
  axes[0, 0].set_title("M_t (trust-weighted estimate)")
  axes[0, 1].imshow(p_true, cmap="magma")
  axes[0, 1].set_title("P_true(s)  (from oracle Y_t, full grid)")
  axes[0, 2].imshow(p_pred, cmap="magma")
  axes[0, 2].set_title("P_pred(s)  (g_f output, full grid)")
  axes[1, 0].hist(kls, bins=30)
  axes[1, 0].set_title("KL(P_true || P_pred) across test states")
  axes[1, 0].set_xlabel("KL divergence")
  axes[1, 1].hist(overlaps, bins=np.linspace(0, 1, 11))
  axes[1, 1].set_title(f"Top-{k} cell overlap across test states")
  axes[1, 1].set_xlabel("fraction overlap")
  axes[1, 2].scatter(sample_Y.reshape(-1), sample_R.reshape(-1), s=10, alpha=0.6)
  axes[1, 2].set_xlabel("oracle Y_t(s)")
  axes[1, 2].set_ylabel("predicted R_t(s)")
  axes[1, 2].set_title("Y_t vs R_t (one state, all cells)")
  for ax in axes[0]:
    plt.colorbar(ax.images[0], ax=ax, fraction=0.046)
  plt.tight_layout()
  plt.savefig("gfunc_validation.png", dpi=130)
  print("saved plot to gfunc_validation.png")

# %%
ALPHA_EPISODES = 3000
G_DATA_EPISODES = 3000
G_MAX_EPOCHS = 300
EVAL_EPISODES = 100

print("=== training alpha_net ===")
alpha_net, alpha_loss = train_alpha_net(episodes=ALPHA_EPISODES)

print("\n=== generating g_f training data ===")
X, Y = build_dataset(alpha_net, episodes=G_DATA_EPISODES)
print("dataset:", X.shape, Y.shape, " Y stats:",
      float(Y.min()), float(Y.max()), float(Y.mean()))

print("\n=== training g_f (full grid, visited/unvisited loss-balanced) ===")
gnet, g_loss = train_gnet(X, Y, max_epochs=G_MAX_EPOCHS)

print("\n=== validating g_f (full grid, with visited/unvisited breakdown) ===")
kls, overlaps, sample = evaluate(gnet, alpha_net, episodes=EVAL_EPISODES)
plot_validation(kls, overlaps, sample)

torch.save(alpha_net.state_dict(), "alpha_net.pt")
torch.save(gnet.state_dict(), "gnet.pt")
print("\nsaved alpha_net.pt and gnet.pt")
# Out:
# === training alpha_net ===
# [alpha_net] episode 100/3000  avg loss 0.00626
# [alpha_net] episode 200/3000  avg loss 0.00388
# [alpha_net] episode 300/3000  avg loss 0.00453
# [alpha_net] episode 400/3000  avg loss 0.00514
# [alpha_net] episode 500/3000  avg loss 0.00764
# [alpha_net] episode 600/3000  avg loss 0.00764
# [alpha_net] episode 700/3000  avg loss 0.00980
# [alpha_net] episode 800/3000  avg loss 0.00696
# [alpha_net] episode 900/3000  avg loss 0.00569
# [alpha_net] episode 1000/3000  avg loss 0.00654
# [alpha_net] episode 1100/3000  avg loss 0.00687
# [alpha_net] episode 1200/3000  avg loss 0.00774
# [alpha_net] episode 1300/3000  avg loss 0.00546
# [alpha_net] episode 1400/3000  avg loss 0.00780
# [alpha_net] episode 1500/3000  avg loss 0.00355
# [alpha_net] episode 1600/3000  avg loss 0.00630
# [alpha_net] episode 1700/3000  avg loss 0.00763
# [alpha_net] episode 1800/3000  avg loss 0.00718
# [alpha_net] episode 1900/3000  avg loss 0.00416
# [alpha_net] episode 2000/3000  avg loss 0.00587
# [alpha_net] episode 2100/3000  avg loss 0.00459
# [alpha_net] episode 2200/3000  avg loss 0.00574
# [alpha_net] episode 2300/3000  avg loss 0.00419
# [alpha_net] episode 2400/3000  avg loss 0.00382
# [alpha_net] episode 2500/3000  avg loss 0.00659
# [alpha_net] episode 2600/3000  avg loss 0.00442
# [alpha_net] episode 2700/3000  avg loss 0.00464
# [alpha_net] episode 2800/3000  avg loss 0.00609
# [alpha_net] episode 2900/3000  avg loss 0.00418
# [alpha_net] episode 3000/3000  avg loss 0.01062
#
# === generating g_f training data ===
# [g_f data] generated 25/3000 episodes (3750 state samples so far)
# [g_f data] generated 50/3000 episodes (7500 state samples so far)
# [g_f data] generated 75/3000 episodes (11250 state samples so far)
# [g_f data] generated 100/3000 episodes (15000 state samples so far)
# [g_f data] generated 125/3000 episodes (18750 state samples so far)
# [g_f data] generated 150/3000 episodes (22500 state samples so far)
# [g_f data] generated 175/3000 episodes (26250 state samples so far)
# [g_f data] generated 200/3000 episodes (30000 state samples so far)
# [g_f data] generated 225/3000 episodes (33750 state samples so far)
# [g_f data] generated 250/3000 episodes (37500 state samples so far)
# [g_f data] generated 275/3000 episodes (41250 state samples so far)
# [g_f data] generated 300/3000 episodes (45000 state samples so far)
# [g_f data] generated 325/3000 episodes (48750 state samples so far)
# [g_f data] generated 350/3000 episodes (52500 state samples so far)
# [g_f data] generated 375/3000 episodes (56250 state samples so far)
# [g_f data] generated 400/3000 episodes (60000 state samples so far)
# [g_f data] generated 425/3000 episodes (63750 state samples so far)
# [g_f data] generated 450/3000 episodes (67500 state samples so far)
# [g_f data] generated 475/3000 episodes (71250 state samples so far)
# [g_f data] generated 500/3000 episodes (75000 state samples so far)
# [g_f data] generated 525/3000 episodes (78750 state samples so far)
# [g_f data] generated 550/3000 episodes (82500 state samples so far)
# [g_f data] generated 575/3000 episodes (86250 state samples so far)
# [g_f data] generated 600/3000 episodes (90000 state samples so far)
# [g_f data] generated 625/3000 episodes (93750 state samples so far)
# [g_f data] generated 650/3000 episodes (97500 state samples so far)
# [g_f data] generated 675/3000 episodes (101250 state samples so far)
# [g_f data] generated 700/3000 episodes (105000 state samples so far)
# [g_f data] generated 725/3000 episodes (108750 state samples so far)
# [g_f data] generated 750/3000 episodes (112500 state samples so far)
# [g_f data] generated 775/3000 episodes (116250 state samples so far)
# [g_f data] generated 800/3000 episodes (120000 state samples so far)
# [g_f data] generated 825/3000 episodes (123750 state samples so far)
# [g_f data] generated 850/3000 episodes (127500 state samples so far)
# [g_f data] generated 875/3000 episodes (131250 state samples so far)
# [g_f data] generated 900/3000 episodes (135000 state samples so far)
# [g_f data] generated 925/3000 episodes (138750 state samples so far)
# [g_f data] generated 950/3000 episodes (142500 state samples so far)
# [g_f data] generated 975/3000 episodes (146250 state samples so far)
# [g_f data] generated 1000/3000 episodes (150000 state samples so far)
# [g_f data] generated 1025/3000 episodes (153750 state samples so far)
# [g_f data] generated 1050/3000 episodes (157500 state samples so far)
# [g_f data] generated 1075/3000 episodes (161250 state samples so far)
# [g_f data] generated 1100/3000 episodes (165000 state samples so far)
# [g_f data] generated 1125/3000 episodes (168750 state samples so far)
# [g_f data] generated 1150/3000 episodes (172500 state samples so far)
# [g_f data] generated 1175/3000 episodes (176250 state samples so far)
# [g_f data] generated 1200/3000 episodes (180000 state samples so far)
# [g_f data] generated 1225/3000 episodes (183750 state samples so far)
# [g_f data] generated 1250/3000 episodes (187500 state samples so far)
# [g_f data] generated 1275/3000 episodes (191250 state samples so far)
# [g_f data] generated 1300/3000 episodes (195000 state samples so far)
# [g_f data] generated 1325/3000 episodes (198750 state samples so far)
# [g_f data] generated 1350/3000 episodes (202500 state samples so far)
# [g_f data] generated 1375/3000 episodes (206250 state samples so far)
# [g_f data] generated 1400/3000 episodes (210000 state samples so far)
# [g_f data] generated 1425/3000 episodes (213750 state samples so far)
# [g_f data] generated 1450/3000 episodes (217500 state samples so far)
# [g_f data] generated 1475/3000 episodes (221250 state samples so far)
# [g_f data] generated 1500/3000 episodes (225000 state samples so far)
# [g_f data] generated 1525/3000 episodes (228750 state samples so far)
# [g_f data] generated 1550/3000 episodes (232500 state samples so far)
# [g_f data] generated 1575/3000 episodes (236250 state samples so far)
# [g_f data] generated 1600/3000 episodes (240000 state samples so far)
# [g_f data] generated 1625/3000 episodes (243750 state samples so far)
# [g_f data] generated 1650/3000 episodes (247500 state samples so far)
# [g_f data] generated 1675/3000 episodes (251250 state samples so far)
# [g_f data] generated 1700/3000 episodes (255000 state samples so far)
# [g_f data] generated 1725/3000 episodes (258750 state samples so far)
# [g_f data] generated 1750/3000 episodes (262500 state samples so far)
# [g_f data] generated 1775/3000 episodes (266250 state samples so far)
# [g_f data] generated 1800/3000 episodes (270000 state samples so far)
# [g_f data] generated 1825/3000 episodes (273750 state samples so far)
# [g_f data] generated 1850/3000 episodes (277500 state samples so far)
# [g_f data] generated 1875/3000 episodes (281250 state samples so far)
# [g_f data] generated 1900/3000 episodes (285000 state samples so far)
# [g_f data] generated 1925/3000 episodes (288750 state samples so far)
# [g_f data] generated 1950/3000 episodes (292500 state samples so far)
# [g_f data] generated 1975/3000 episodes (296250 state samples so far)
# [g_f data] generated 2000/3000 episodes (300000 state samples so far)
# [g_f data] generated 2025/3000 episodes (303750 state samples so far)
# [g_f data] generated 2050/3000 episodes (307500 state samples so far)
# [g_f data] generated 2075/3000 episodes (311250 state samples so far)
# [g_f data] generated 2100/3000 episodes (315000 state samples so far)
# [g_f data] generated 2125/3000 episodes (318750 state samples so far)
# [g_f data] generated 2150/3000 episodes (322500 state samples so far)
# [g_f data] generated 2175/3000 episodes (326250 state samples so far)
# [g_f data] generated 2200/3000 episodes (330000 state samples so far)
# [g_f data] generated 2225/3000 episodes (333750 state samples so far)
# [g_f data] generated 2250/3000 episodes (337500 state samples so far)
# [g_f data] generated 2275/3000 episodes (341250 state samples so far)
# [g_f data] generated 2300/3000 episodes (345000 state samples so far)
# [g_f data] generated 2325/3000 episodes (348750 state samples so far)
# [g_f data] generated 2350/3000 episodes (352500 state samples so far)
# [g_f data] generated 2375/3000 episodes (356250 state samples so far)
# [g_f data] generated 2400/3000 episodes (360000 state samples so far)
# [g_f data] generated 2425/3000 episodes (363750 state samples so far)
# [g_f data] generated 2450/3000 episodes (367500 state samples so far)
# [g_f data] generated 2475/3000 episodes (371250 state samples so far)
# [g_f data] generated 2500/3000 episodes (375000 state samples so far)
# [g_f data] generated 2525/3000 episodes (378750 state samples so far)
# [g_f data] generated 2550/3000 episodes (382500 state samples so far)
# [g_f data] generated 2575/3000 episodes (386250 state samples so far)
# [g_f data] generated 2600/3000 episodes (390000 state samples so far)
# [g_f data] generated 2625/3000 episodes (393750 state samples so far)
# [g_f data] generated 2650/3000 episodes (397500 state samples so far)
# [g_f data] generated 2675/3000 episodes (401250 state samples so far)
# [g_f data] generated 2700/3000 episodes (405000 state samples so far)
# [g_f data] generated 2725/3000 episodes (408750 state samples so far)
# [g_f data] generated 2750/3000 episodes (412500 state samples so far)
# [g_f data] generated 2775/3000 episodes (416250 state samples so far)
# [g_f data] generated 2800/3000 episodes (420000 state samples so far)
# [g_f data] generated 2825/3000 episodes (423750 state samples so far)
# [g_f data] generated 2850/3000 episodes (427500 state samples so far)
# [g_f data] generated 2875/3000 episodes (431250 state samples so far)
# [g_f data] generated 2900/3000 episodes (435000 state samples so far)
# [g_f data] generated 2925/3000 episodes (438750 state samples so far)
# [g_f data] generated 2950/3000 episodes (442500 state samples so far)
# [g_f data] generated 2975/3000 episodes (446250 state samples so far)
# [g_f data] generated 3000/3000 episodes (450000 state samples so far)
# dataset: torch.Size([450000, 3, 12, 12]) torch.Size([450000, 12, 12])  Y stats: 0.0 20.0 0.6776199340820312
#
# === training g_f (full grid, visited/unvisited loss-balanced) ===
# [g_f train] epoch 1/300  avg loss 4.352245
# [g_f train] epoch 2/300  avg loss 3.332818
# [g_f train] epoch 3/300  avg loss 3.007632
# [g_f train] epoch 4/300  avg loss 2.816659
# [g_f train] epoch 5/300  avg loss 2.710359
# [g_f train] epoch 6/300  avg loss 2.642523
# [g_f train] epoch 7/300  avg loss 2.590164
# [g_f train] epoch 8/300  avg loss 2.547305
# [g_f train] epoch 9/300  avg loss 2.510587
# [g_f train] epoch 10/300  avg loss 2.485970
# [g_f train] epoch 11/300  avg loss 2.460269
# [g_f train] epoch 12/300  avg loss 2.438021
# [g_f train] epoch 13/300  avg loss 2.414530
# [g_f train] epoch 14/300  avg loss 2.399920
# [g_f train] epoch 15/300  avg loss 2.385929
# [g_f train] epoch 16/300  avg loss 2.370803
# [g_f train] epoch 17/300  avg loss 2.359182
# [g_f train] epoch 18/300  avg loss 2.346375
# [g_f train] epoch 19/300  avg loss 2.335921
# [g_f train] epoch 20/300  avg loss 2.325820
# [g_f train] epoch 21/300  avg loss 2.315376
# [g_f train] epoch 22/300  avg loss 2.303944
# [g_f train] epoch 23/300  avg loss 2.301095
# [g_f train] epoch 24/300  avg loss 2.288860
# [g_f train] epoch 25/300  avg loss 2.285027
# [g_f train] epoch 26/300  avg loss 2.277670
# [g_f train] epoch 27/300  avg loss 2.267396
# [g_f train] epoch 28/300  avg loss 2.268631
# [g_f train] epoch 29/300  avg loss 2.264527
# [g_f train] epoch 30/300  avg loss 2.258239
# [g_f train] epoch 31/300  avg loss 2.259034
# [g_f train] epoch 32/300  avg loss 2.248333
# [g_f train] epoch 33/300  avg loss 2.242714
# [g_f train] epoch 34/300  avg loss 2.238074
# [g_f train] epoch 35/300  avg loss 2.239901
# [g_f train] epoch 36/300  avg loss 2.233326
# [g_f train] epoch 37/300  avg loss 2.229142
# [g_f train] epoch 38/300  avg loss 2.225764
# [g_f train] epoch 39/300  avg loss 2.220980
# [g_f train] epoch 40/300  avg loss 2.220145
# [g_f train] epoch 41/300  avg loss 2.212350
# [g_f train] epoch 42/300  avg loss 2.211346
# [g_f train] epoch 43/300  avg loss 2.210045
# [g_f train] epoch 44/300  avg loss 2.207489
# [g_f train] epoch 45/300  avg loss 2.205867
# [g_f train] epoch 46/300  avg loss 2.210448
# [g_f train] epoch 47/300  avg loss 2.201425
# [g_f train] epoch 48/300  avg loss 2.200347
# [g_f train] epoch 49/300  avg loss 2.197050
# [g_f train] epoch 50/300  avg loss 2.196192
# [g_f train] epoch 51/300  avg loss 2.195375
# [g_f train] epoch 52/300  avg loss 2.192168
# [g_f train] epoch 53/300  avg loss 2.192354
# [g_f train] epoch 54/300  avg loss 2.190761
# [g_f train] epoch 55/300  avg loss 2.190110
# [g_f train] epoch 56/300  avg loss 2.189016
# [g_f train] epoch 57/300  avg loss 2.188134
# [g_f train] epoch 58/300  avg loss 2.183403
# [g_f train] epoch 59/300  avg loss 2.184283
# [g_f train] epoch 60/300  avg loss 2.183148
# [g_f train] epoch 61/300  avg loss 2.178239
# [g_f train] epoch 62/300  avg loss 2.180743
# [g_f train] epoch 63/300  avg loss 2.173013
# [g_f train] epoch 64/300  avg loss 2.179261
# [g_f train] epoch 65/300  avg loss 2.178994
# [g_f train] epoch 66/300  avg loss 2.171968
# [g_f train] epoch 67/300  avg loss 2.176069
# [g_f train] epoch 68/300  avg loss 2.173701
# [g_f train] epoch 69/300  avg loss 2.170300
# [g_f train] epoch 70/300  avg loss 2.172831
# [g_f train] epoch 71/300  avg loss 2.170273
# [g_f train] epoch 72/300  avg loss 2.167308
# [g_f train] epoch 73/300  avg loss 2.168764
# [g_f train] epoch 74/300  avg loss 2.168246
# [g_f train] epoch 75/300  avg loss 2.163521
# [g_f train] epoch 76/300  avg loss 2.166068
# [g_f train] epoch 77/300  avg loss 2.162745
# [g_f train] epoch 78/300  avg loss 2.165546
# [g_f train] epoch 79/300  avg loss 2.162379
# [g_f train] epoch 80/300  avg loss 2.163447
# [g_f train] epoch 81/300  avg loss 2.164196
# [g_f train] epoch 82/300  avg loss 2.161066
# [g_f train] epoch 83/300  avg loss 2.160184
# [g_f train] epoch 84/300  avg loss 2.156802
# [g_f train] epoch 85/300  avg loss 2.158483
# [g_f train] epoch 86/300  avg loss 2.162186
# [g_f train] epoch 87/300  avg loss 2.160989
# [g_f train] epoch 88/300  avg loss 2.157909
# [g_f train] epoch 89/300  avg loss 2.159727
# [g_f train] epoch 90/300  avg loss 2.158329
# [g_f train] epoch 91/300  avg loss 2.156726
# [g_f train] epoch 92/300  avg loss 2.161458
# [g_f train] plateaued at epoch 92, stopping early
#
# === validating g_f (full grid, with visited/unvisited breakdown) ===
# [g_f eval] FULL GRID   mean KL = 0.6519  mean top-5 overlap = 0.676
# [g_f eval] visited-only    mean KL = 1.0641  mean top-5 overlap = 0.586  (n=15000)
# [g_f eval] unvisited-only  mean KL = 0.0868  mean top-5 overlap = 0.833  (n=7682)
# saved plot to gfunc_validation.png
#
# saved alpha_net.pt and gnet.pt
