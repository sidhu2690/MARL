# %% [markdown]
# <a href="https://colab.research.google.com/github/sidhu2690/MARL/blob/main/probability_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt


GRID = 12
N_ROBOTS = 12
ADV_FRAC = 0.34
STEPS = 150
EPSILON = 0.05
CONTRA_THRESH = 0.2
SEED = 40

rng = np.random.default_rng(SEED)
torch.manual_seed(SEED)


def make_true_map(grid):
  xs, ys = np.meshgrid(np.arange(grid), np.arange(grid))
  field = np.zeros((grid, grid))
  for _ in range(5):
    cx, cy = rng.uniform(0, grid, 2)
    amp = rng.uniform(0.5, 1.0)
    sigma = rng.uniform(1.5, 3.5)
    field += amp * np.exp(-((xs - cx) ** 2 + (ys - cy) ** 2) / (2 * sigma ** 2))
  field = (field - field.min()) / (field.max() - field.min() + 1e-8)
  return field


def random_walk(grid, steps):
  pos = rng.integers(0, grid, size=2)
  cells = []
  for _ in range(steps):
    while True:
      move = rng.choice([-1, 0, 1], size=2)
      new_pos = np.clip(pos + move, 0, grid - 1)
      if not np.array_equal(new_pos, pos):
        break
    pos = new_pos
    cells.append(tuple(pos))
  return cells


def make_adv_mask(n_robots, adv_frac):
  n_adv = int(n_robots * adv_frac)
  mask = np.array([False] * (n_robots - n_adv) + [True] * n_adv)
  rng.shuffle(mask)
  return mask

def report_value(true_val, adversarial):
  if adversarial:
    val = true_val + rng.choice([-1, 1]) * rng.uniform(0.3, 0.6) + rng.normal(0, 0.1)
  else:
    val = true_val + rng.normal(0, 0.02)
  return float(np.clip(val, 0, 1))

# %%
# Part 1: alpha_net

class AlphaNet(nn.Module):
  def __init__(self):
    super().__init__()
    self.net = nn.Sequential(
      nn.Linear(3, 16), nn.ReLU(),
      nn.Linear(16, 8), nn.ReLU(),
      nn.Linear(8, 1), nn.Sigmoid(),
    )
  def forward(self, feats):
    return self.net(feats).squeeze(-1)



def train_alpha_net(episodes=400, lr=2e-3):
  alpha_net = AlphaNet()
  optimizer = torch.optim.Adam(alpha_net.parameters(), lr=lr)
  loss_history = []
  for ep in range(episodes):
    TRUE_MAP = make_true_map(GRID)
    is_adv = make_adv_mask(N_ROBOTS, ADV_FRAC)
    walks = [random_walk(GRID, STEPS) for _ in range(N_ROBOTS)]
    c = np.zeros(N_ROBOTS)
    D_sum = np.zeros(N_ROBOTS)
    D_n = np.zeros(N_ROBOTS)
    cell_reports = {}
    ep_loss = 0.0
    for t in range(STEPS):
      touched_cells = set()
      for i in range(N_ROBOTS):
        cell = walks[i][t]
        r_i = report_value(TRUE_MAP[cell], is_adv[i])
        others = cell_reports.get(cell, [])
        if others:
          residuals = [abs(r_i - r_j) for _, r_j in others]
          D_sum[i] += float(np.mean(residuals))
          D_n[i] += 1
          for j, r_j in others:
            if abs(r_i - r_j) > CONTRA_THRESH:
              c[i] += 1
              c[j] += 1
        cell_reports.setdefault(cell, []).append((i, r_i))
        touched_cells.add(cell)
      mu_c, sigma_c = c.mean(), c.std()
      z = (c - mu_c) / (sigma_c + EPSILON)
      D = np.divide(D_sum, D_n, out=np.zeros_like(D_sum), where=D_n > 0)
      c_norm = c / (t + 1)
      feats = torch.tensor(np.stack([c_norm, z, D], axis=1), dtype=torch.float32)
      alpha = alpha_net(feats)
      step_loss = 0.0
      for cell in touched_cells:
        reports = cell_reports[cell]
        idx = torch.tensor([r for r, _ in reports])
        vals = torch.tensor([v for _, v in reports], dtype=torch.float32)
        a = alpha[idx]
        M = (a * vals).sum() / (a.sum() + EPSILON)
        step_loss = step_loss + (TRUE_MAP[cell] - M) ** 2
      step_loss = step_loss / len(touched_cells)
      optimizer.zero_grad()
      step_loss.backward()
      optimizer.step()
      ep_loss += step_loss.item()
    loss_history.append(ep_loss / STEPS)
    if (ep + 1) % 100 == 0:
      print(f"[alpha_net] episode {ep+1}/{episodes}  avg loss {loss_history[-1]:.5f}")
  return alpha_net, loss_history

# %%
# Part 2:  Produce (M_t, U_t, N_t) -> Y_t training pairs

PRIOR = 0     # M_t(s) prior for never-observed cells
Y_SCALE = 20.0


def rollout_episode(alpha_net):
  TRUE_MAP = make_true_map(GRID)
  is_adv = make_adv_mask(N_ROBOTS, ADV_FRAC)
  walks = [random_walk(GRID, STEPS) for _ in range(N_ROBOTS)]
  c = np.zeros(N_ROBOTS)
  D_sum = np.zeros(N_ROBOTS)
  D_n = np.zeros(N_ROBOTS)
  cell_reports = {}
  xs, ys = [], []
  for t in range(STEPS):
    for i in range(N_ROBOTS):
      cell = walks[i][t]
      r_i = report_value(TRUE_MAP[cell], is_adv[i])
      others = cell_reports.get(cell, [])
      if others:
        residuals = [abs(r_i - r_j) for _, r_j in others]
        D_sum[i] += float(np.mean(residuals))
        D_n[i] += 1
        for j, r_j in others:
          if abs(r_i - r_j) > CONTRA_THRESH:
            c[i] += 1
            c[j] += 1
      cell_reports.setdefault(cell, []).append((i, r_i))
    mu_c, sigma_c = c.mean(), c.std()
    z = (c - mu_c) / (sigma_c + EPSILON)
    D = np.divide(D_sum, D_n, out=np.zeros_like(D_sum), where=D_n > 0)
    c_norm = c / (t + 1)
    feats = torch.tensor(np.stack([c_norm, z, D], axis=1), dtype=torch.float32)
    with torch.no_grad():
      alpha = alpha_net(feats).numpy()
    W_sum = np.zeros((GRID, GRID))
    A_sum = np.zeros((GRID, GRID))
    N_map = np.zeros((GRID, GRID))
    for cell, reports in cell_reports.items():
      idx = np.array([r for r, _ in reports])
      vals = np.array([v for _, v in reports])
      a = alpha[idx]
      W_sum[cell] = (a * vals).sum()
      A_sum[cell] = a.sum()
      N_map[cell] = len(reports)
    M_t = np.where(A_sum > 0, W_sum / np.maximum(A_sum, 1e-8), PRIOR)
    U_t = A_sum
    N_t = N_map
    err_old = (TRUE_MAP - M_t) ** 2
    r_new = TRUE_MAP.copy()
    M_next = (W_sum + r_new) / (A_sum + 1.0)
    err_new = (TRUE_MAP - M_next) ** 2
    Y_t = np.clip(err_old - err_new, 0, None)
    xs.append(np.stack([M_t, U_t, N_t]).astype(np.float32))
    ys.append(Y_t.astype(np.float32))
  return xs, ys

# %%
# Part 3: g_f -- CNN

class GNet(nn.Module):
  def __init__(self):
    super().__init__()
    self.net = nn.Sequential(
      nn.Conv2d(3, 16, 3, padding=1), nn.ReLU(),
      nn.Conv2d(16, 16, 3, padding=2, dilation=2), nn.ReLU(),
      nn.Conv2d(16, 16, 3, padding=1), nn.ReLU(),
      nn.Conv2d(16, 1, 3, padding=1),
    )
  def forward(self, x):
    return self.net(x).squeeze(1)

def predict_R(gnet, X_t):
  with torch.no_grad():
    raw = gnet(torch.tensor(X_t, dtype=torch.float32).unsqueeze(0)).squeeze(0)
  return (raw / Y_SCALE).numpy()

def build_dataset(alpha_net, episodes):
  X_all, Y_all = [], []
  for ep in range(episodes):
    xs, ys = rollout_episode(alpha_net)
    X_all.extend(xs)
    Y_all.extend(ys)
    if (ep + 1) % 25 == 0:
      print(f"[g_f data] generated {ep+1}/{episodes} episodes "
            f"({len(X_all)} state samples so far)")
  X = torch.tensor(np.stack(X_all), dtype=torch.float32)
  Y = torch.tensor(np.stack(Y_all), dtype=torch.float32) * Y_SCALE
  return X, Y



def train_gnet(X, Y, max_epochs=150, lr=1e-3, batch_size=64,
               patience=8, min_delta=1e-4, balance_visited=True):
  gnet = GNet()
  optimizer = torch.optim.Adam(gnet.parameters(), lr=lr)
  n = X.shape[0]
  loss_history = []
  best_loss = float("inf")
  bad_epochs = 0
  for epoch in range(max_epochs):
    perm = torch.randperm(n)
    epoch_loss = 0.0
    n_batches = 0
    for start in range(0, n, batch_size):
      idx = perm[start:start + batch_size]
      xb, yb = X[idx], Y[idx]
      pred = gnet(xb)
      if balance_visited:
        visited = (xb[:, 2] > 0).float()
        n_vis = visited.sum().clamp(min=1.0)
        n_unvis = (1 - visited).sum().clamp(min=1.0)
        w = visited / n_vis + (1 - visited) / n_unvis
        loss = ((pred - yb) ** 2 * w).sum() / 2.0
      else:
        loss = ((pred - yb) ** 2).mean()
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      epoch_loss += loss.item()
      n_batches += 1
    avg_loss = epoch_loss / n_batches
    loss_history.append(avg_loss)
    print(f"[g_f train] epoch {epoch+1}/{max_epochs}  avg loss {avg_loss:.6f}")
    if best_loss - avg_loss > min_delta:
      best_loss = avg_loss
      bad_epochs = 0
    else:
      bad_epochs += 1
      if bad_epochs >= patience:
        print(f"[g_f train] plateaued at epoch {epoch+1}, stopping early")
        break
  return gnet, loss_history

# %%
# Part 4: validation

def normalize_nonneg(y):
  y = np.clip(y, 0, None)
  s = y.sum()
  if s <= 1e-12:
    return np.full_like(y, 1.0 / y.size)
  return y / s

def kl_divergence(p_true, p_pred, eps=1e-8):
  p_true = np.clip(p_true, eps, None)
  p_pred = np.clip(p_pred, eps, None)
  return float(np.sum(p_true * np.log(p_true / p_pred)))

def topk_overlap(y_true_flat, r_pred_flat, k=5):
  k = min(k, y_true_flat.size)
  true_top = set(np.argsort(y_true_flat)[-k:])
  pred_top = set(np.argsort(r_pred_flat)[-k:])
  return len(true_top & pred_top) / k

def evaluate(gnet, alpha_net, episodes=20, k=5):
  kls, overlaps = [], []
  kls_vis, overlaps_vis = [], []
  kls_unvis, overlaps_unvis = [], []
  sample_X, sample_Y, sample_R = None, None, None
  for ep in range(episodes):
    xs, ys = rollout_episode(alpha_net)
    for X_t, Y_t in zip(xs, ys):
      R_t = predict_R(gnet, X_t)
      N_t = X_t[2]
      p_true = normalize_nonneg(Y_t)
      p_pred = normalize_nonneg(R_t)
      kls.append(kl_divergence(p_true, p_pred))
      overlaps.append(topk_overlap(Y_t.reshape(-1), R_t.reshape(-1), k=k))
      vis_mask = N_t > 0
      if vis_mask.sum() >= k:
        yv, rv = Y_t[vis_mask], R_t[vis_mask]
        kls_vis.append(kl_divergence(normalize_nonneg(yv), normalize_nonneg(rv)))
        overlaps_vis.append(topk_overlap(yv, rv, k=k))
      unvis_mask = N_t == 0
      if unvis_mask.sum() >= k:
        yu, ru = Y_t[unvis_mask], R_t[unvis_mask]
        kls_unvis.append(kl_divergence(normalize_nonneg(yu), normalize_nonneg(ru)))
        overlaps_unvis.append(topk_overlap(yu, ru, k=k))
      if sample_X is None and Y_t.sum() > 1e-6:
        sample_X, sample_Y, sample_R = X_t, Y_t, R_t
  print(f"[g_f eval] FULL GRID   mean KL = {np.mean(kls):.4f}  "
        f"mean top-{k} overlap = {np.mean(overlaps):.3f}")
  print(f"[g_f eval] visited-only    mean KL = {np.mean(kls_vis):.4f}  "
        f"mean top-{k} overlap = {np.mean(overlaps_vis):.3f}  (n={len(kls_vis)})")
  print(f"[g_f eval] unvisited-only  mean KL = {np.mean(kls_unvis):.4f}  "
        f"mean top-{k} overlap = {np.mean(overlaps_unvis):.3f}  (n={len(kls_unvis)})")
  return kls, overlaps, (sample_X, sample_Y, sample_R)



def plot_validation(kls, overlaps, sample, k=5):
  sample_X, sample_Y, sample_R = sample
  p_true = normalize_nonneg(sample_Y)
  p_pred = normalize_nonneg(sample_R)
  fig, axes = plt.subplots(2, 3, figsize=(13, 8))
  axes[0, 0].imshow(sample_X[0], cmap="viridis")
  axes[0, 0].set_title("M_t (trust-weighted estimate)")
  axes[0, 1].imshow(p_true, cmap="magma")
  axes[0, 1].set_title("P_true(s)  (from oracle Y_t, full grid)")
  axes[0, 2].imshow(p_pred, cmap="magma")
  axes[0, 2].set_title("P_pred(s)  (g_f output, full grid)")
  axes[1, 0].hist(kls, bins=30)
  axes[1, 0].set_title("KL(P_true || P_pred) across test states")
  axes[1, 0].set_xlabel("KL divergence")
  axes[1, 1].hist(overlaps, bins=np.linspace(0, 1, 11))
  axes[1, 1].set_title(f"Top-{k} cell overlap across test states")
  axes[1, 1].set_xlabel("fraction overlap")
  axes[1, 2].scatter(sample_Y.reshape(-1), sample_R.reshape(-1), s=10, alpha=0.6)
  axes[1, 2].set_xlabel("oracle Y_t(s)")
  axes[1, 2].set_ylabel("predicted R_t(s)")
  axes[1, 2].set_title("Y_t vs R_t (one state, all cells)")
  for ax in axes[0]:
    plt.colorbar(ax.images[0], ax=ax, fraction=0.046)
  plt.tight_layout()
  plt.savefig("gfunc_validation.png", dpi=130)
  print("saved plot to gfunc_validation.png")

# %%
ALPHA_EPISODES = 1000
G_DATA_EPISODES = 1000
G_MAX_EPOCHS = 150
EVAL_EPISODES = 50

print("=== training alpha_net ===")
alpha_net, alpha_loss = train_alpha_net(episodes=ALPHA_EPISODES)

print("\n=== generating g_f training data ===")
X, Y = build_dataset(alpha_net, episodes=G_DATA_EPISODES)
print("dataset:", X.shape, Y.shape, " Y stats:",
      float(Y.min()), float(Y.max()), float(Y.mean()))

print("\n=== training g_f (full grid, visited/unvisited loss-balanced) ===")
gnet, g_loss = train_gnet(X, Y, max_epochs=G_MAX_EPOCHS)

print("\n=== validating g_f (full grid, with visited/unvisited breakdown) ===")
kls, overlaps, sample = evaluate(gnet, alpha_net, episodes=EVAL_EPISODES)
plot_validation(kls, overlaps, sample)

torch.save(alpha_net.state_dict(), "alpha_net.pt")
torch.save(gnet.state_dict(), "gnet.pt")
print("\nsaved alpha_net.pt and gnet.pt")
# Out:
# === training alpha_net ===
# [alpha_net] episode 100/1000  avg loss 0.00626
# [alpha_net] episode 200/1000  avg loss 0.00383
# [alpha_net] episode 300/1000  avg loss 0.00452
# [alpha_net] episode 400/1000  avg loss 0.00508
# [alpha_net] episode 500/1000  avg loss 0.00769
# [alpha_net] episode 600/1000  avg loss 0.00776
# [alpha_net] episode 700/1000  avg loss 0.00988
# [alpha_net] episode 800/1000  avg loss 0.00678
# [alpha_net] episode 900/1000  avg loss 0.00579
# [alpha_net] episode 1000/1000  avg loss 0.00657
#
# === generating g_f training data ===
# [g_f data] generated 25/1000 episodes (3750 state samples so far)
# [g_f data] generated 50/1000 episodes (7500 state samples so far)
# [g_f data] generated 75/1000 episodes (11250 state samples so far)
# [g_f data] generated 100/1000 episodes (15000 state samples so far)
# [g_f data] generated 125/1000 episodes (18750 state samples so far)
# [g_f data] generated 150/1000 episodes (22500 state samples so far)
# [g_f data] generated 175/1000 episodes (26250 state samples so far)
# [g_f data] generated 200/1000 episodes (30000 state samples so far)
# [g_f data] generated 225/1000 episodes (33750 state samples so far)
# [g_f data] generated 250/1000 episodes (37500 state samples so far)
# [g_f data] generated 275/1000 episodes (41250 state samples so far)
# [g_f data] generated 300/1000 episodes (45000 state samples so far)
# [g_f data] generated 325/1000 episodes (48750 state samples so far)
# [g_f data] generated 350/1000 episodes (52500 state samples so far)
# [g_f data] generated 375/1000 episodes (56250 state samples so far)
# [g_f data] generated 400/1000 episodes (60000 state samples so far)
# [g_f data] generated 425/1000 episodes (63750 state samples so far)
# [g_f data] generated 450/1000 episodes (67500 state samples so far)
# [g_f data] generated 475/1000 episodes (71250 state samples so far)
# [g_f data] generated 500/1000 episodes (75000 state samples so far)
# [g_f data] generated 525/1000 episodes (78750 state samples so far)
# [g_f data] generated 550/1000 episodes (82500 state samples so far)
# [g_f data] generated 575/1000 episodes (86250 state samples so far)
# [g_f data] generated 600/1000 episodes (90000 state samples so far)
# [g_f data] generated 625/1000 episodes (93750 state samples so far)
# [g_f data] generated 650/1000 episodes (97500 state samples so far)
# [g_f data] generated 675/1000 episodes (101250 state samples so far)
# [g_f data] generated 700/1000 episodes (105000 state samples so far)
# [g_f data] generated 725/1000 episodes (108750 state samples so far)
# [g_f data] generated 750/1000 episodes (112500 state samples so far)
# [g_f data] generated 775/1000 episodes (116250 state samples so far)
# [g_f data] generated 800/1000 episodes (120000 state samples so far)
# [g_f data] generated 825/1000 episodes (123750 state samples so far)
# [g_f data] generated 850/1000 episodes (127500 state samples so far)
# [g_f data] generated 875/1000 episodes (131250 state samples so far)
# [g_f data] generated 900/1000 episodes (135000 state samples so far)
# [g_f data] generated 925/1000 episodes (138750 state samples so far)
# [g_f data] generated 950/1000 episodes (142500 state samples so far)
# [g_f data] generated 975/1000 episodes (146250 state samples so far)
# [g_f data] generated 1000/1000 episodes (150000 state samples so far)
# dataset: torch.Size([150000, 3, 12, 12]) torch.Size([150000, 12, 12])  Y stats: 0.0 20.0 0.676732063293457
#
# === training g_f (full grid, visited/unvisited loss-balanced) ===
# [g_f train] epoch 1/150  avg loss 5.787200
# [g_f train] epoch 2/150  avg loss 3.702279
# [g_f train] epoch 3/150  avg loss 3.393765
# [g_f train] epoch 4/150  avg loss 3.214733
# [g_f train] epoch 5/150  avg loss 3.095993
# [g_f train] epoch 6/150  avg loss 2.987736
# [g_f train] epoch 7/150  avg loss 2.917693
# [g_f train] epoch 8/150  avg loss 2.839569
# [g_f train] epoch 9/150  avg loss 2.769782
# [g_f train] epoch 10/150  avg loss 2.698778
# [g_f train] epoch 11/150  avg loss 2.635355
# [g_f train] epoch 12/150  avg loss 2.589639
# [g_f train] epoch 13/150  avg loss 2.550257
# [g_f train] epoch 14/150  avg loss 2.523254
# [g_f train] epoch 15/150  avg loss 2.491593
# [g_f train] epoch 16/150  avg loss 2.472904
# [g_f train] epoch 17/150  avg loss 2.450596
# [g_f train] epoch 18/150  avg loss 2.426165
# [g_f train] epoch 19/150  avg loss 2.409682
# [g_f train] epoch 20/150  avg loss 2.403276
# [g_f train] epoch 21/150  avg loss 2.388278
# [g_f train] epoch 22/150  avg loss 2.370954
# [g_f train] epoch 23/150  avg loss 2.356019
# [g_f train] epoch 24/150  avg loss 2.348879
# [g_f train] epoch 25/150  avg loss 2.337446
# [g_f train] epoch 26/150  avg loss 2.325833
# [g_f train] epoch 27/150  avg loss 2.307985
# [g_f train] epoch 28/150  avg loss 2.295670
# [g_f train] epoch 29/150  avg loss 2.299956
# [g_f train] epoch 30/150  avg loss 2.275592
# [g_f train] epoch 31/150  avg loss 2.273943
# [g_f train] epoch 32/150  avg loss 2.267869
# [g_f train] epoch 33/150  avg loss 2.255137
# [g_f train] epoch 34/150  avg loss 2.245044
# [g_f train] epoch 35/150  avg loss 2.249794
# [g_f train] epoch 36/150  avg loss 2.223954
# [g_f train] epoch 37/150  avg loss 2.226175
# [g_f train] epoch 38/150  avg loss 2.221540
# [g_f train] epoch 39/150  avg loss 2.217104
# [g_f train] epoch 40/150  avg loss 2.210368
# [g_f train] epoch 41/150  avg loss 2.199516
# [g_f train] epoch 42/150  avg loss 2.195768
# [g_f train] epoch 43/150  avg loss 2.193400
# [g_f train] epoch 44/150  avg loss 2.180439
# [g_f train] epoch 45/150  avg loss 2.176794
# [g_f train] epoch 46/150  avg loss 2.181159
# [g_f train] epoch 47/150  avg loss 2.170636
# [g_f train] epoch 48/150  avg loss 2.164856
# [g_f train] epoch 49/150  avg loss 2.159648
# [g_f train] epoch 50/150  avg loss 2.154521
# [g_f train] epoch 51/150  avg loss 2.146341
# [g_f train] epoch 52/150  avg loss 2.153981
# [g_f train] epoch 53/150  avg loss 2.147089
# [g_f train] epoch 54/150  avg loss 2.153929
# [g_f train] epoch 55/150  avg loss 2.138091
# [g_f train] epoch 56/150  avg loss 2.135911
# [g_f train] epoch 57/150  avg loss 2.129813
# [g_f train] epoch 58/150  avg loss 2.135815
# [g_f train] epoch 59/150  avg loss 2.124253
# [g_f train] epoch 60/150  avg loss 2.128144
# [g_f train] epoch 61/150  avg loss 2.124241
# [g_f train] epoch 62/150  avg loss 2.122796
# [g_f train] epoch 63/150  avg loss 2.110521
# [g_f train] epoch 64/150  avg loss 2.110401
# [g_f train] epoch 65/150  avg loss 2.113737
# [g_f train] epoch 66/150  avg loss 2.094915
# [g_f train] epoch 67/150  avg loss 2.102881
# [g_f train] epoch 68/150  avg loss 2.100125
# [g_f train] epoch 69/150  avg loss 2.090032
# [g_f train] epoch 70/150  avg loss 2.096209
# [g_f train] epoch 71/150  avg loss 2.098436
# [g_f train] epoch 72/150  avg loss 2.090216
# [g_f train] epoch 73/150  avg loss 2.088963
# [g_f train] epoch 74/150  avg loss 2.087469
# [g_f train] epoch 75/150  avg loss 2.088173
# [g_f train] epoch 76/150  avg loss 2.101775
# [g_f train] epoch 77/150  avg loss 2.081850
# [g_f train] epoch 78/150  avg loss 2.079318
# [g_f train] epoch 79/150  avg loss 2.076697
# [g_f train] epoch 80/150  avg loss 2.076725
# [g_f train] epoch 81/150  avg loss 2.077129
# [g_f train] epoch 82/150  avg loss 2.074145
# [g_f train] epoch 83/150  avg loss 2.078440
# [g_f train] epoch 84/150  avg loss 2.070765
# [g_f train] epoch 85/150  avg loss 2.078179
# [g_f train] epoch 86/150  avg loss 2.077754
# [g_f train] epoch 87/150  avg loss 2.070160
# [g_f train] epoch 88/150  avg loss 2.070347
# [g_f train] epoch 89/150  avg loss 2.062963
# [g_f train] epoch 90/150  avg loss 2.059498
# [g_f train] epoch 91/150  avg loss 2.066667
# [g_f train] epoch 92/150  avg loss 2.052250
# [g_f train] epoch 93/150  avg loss 2.067887
# [g_f train] epoch 94/150  avg loss 2.060775
# [g_f train] epoch 95/150  avg loss 2.054824
# [g_f train] epoch 96/150  avg loss 2.057342
# [g_f train] epoch 97/150  avg loss 2.052135
# [g_f train] epoch 98/150  avg loss 2.057358
# [g_f train] epoch 99/150  avg loss 2.048110
# [g_f train] epoch 100/150  avg loss 2.053223
# [g_f train] epoch 101/150  avg loss 2.044510
# [g_f train] epoch 102/150  avg loss 2.043820
# [g_f train] epoch 103/150  avg loss 2.040473
# [g_f train] epoch 104/150  avg loss 2.048208
# [g_f train] epoch 105/150  avg loss 2.048745
# [g_f train] epoch 106/150  avg loss 2.043943
# [g_f train] epoch 107/150  avg loss 2.041508
# [g_f train] epoch 108/150  avg loss 2.045656
# [g_f train] epoch 109/150  avg loss 2.045430
# [g_f train] epoch 110/150  avg loss 2.043644
# [g_f train] epoch 111/150  avg loss 2.036309
# [g_f train] epoch 112/150  avg loss 2.044881
# [g_f train] epoch 113/150  avg loss 2.043918
# [g_f train] epoch 114/150  avg loss 2.033760
# [g_f train] epoch 115/150  avg loss 2.035786
# [g_f train] epoch 116/150  avg loss 2.033533
# [g_f train] epoch 117/150  avg loss 2.029603
# [g_f train] epoch 118/150  avg loss 2.029181
# [g_f train] epoch 119/150  avg loss 2.032691
# [g_f train] epoch 120/150  avg loss 2.036372
# [g_f train] epoch 121/150  avg loss 2.035656
# [g_f train] epoch 122/150  avg loss 2.025345
# [g_f train] epoch 123/150  avg loss 2.028556
# [g_f train] epoch 124/150  avg loss 2.024355
# [g_f train] epoch 125/150  avg loss 2.034053
# [g_f train] epoch 126/150  avg loss 2.018147
# [g_f train] epoch 127/150  avg loss 2.023799
# [g_f train] epoch 128/150  avg loss 2.015782
# [g_f train] epoch 129/150  avg loss 2.023572
# [g_f train] epoch 130/150  avg loss 2.020723
# [g_f train] epoch 131/150  avg loss 2.012696
# [g_f train] epoch 132/150  avg loss 2.022637
# [g_f train] epoch 133/150  avg loss 2.016464
# [g_f train] epoch 134/150  avg loss 2.017243
# [g_f train] epoch 135/150  avg loss 2.008662
# [g_f train] epoch 136/150  avg loss 2.013577
# [g_f train] epoch 137/150  avg loss 2.021732
# [g_f train] epoch 138/150  avg loss 2.011730
# [g_f train] epoch 139/150  avg loss 2.017688
# [g_f train] epoch 140/150  avg loss 2.015825
# [g_f train] epoch 141/150  avg loss 2.009857
# [g_f train] epoch 142/150  avg loss 2.010849
# [g_f train] epoch 143/150  avg loss 2.006915
# [g_f train] epoch 144/150  avg loss 2.005759
# [g_f train] epoch 145/150  avg loss 2.011307
# [g_f train] epoch 146/150  avg loss 2.008397
# [g_f train] epoch 147/150  avg loss 2.001527
# [g_f train] epoch 148/150  avg loss 2.014919
# [g_f train] epoch 149/150  avg loss 2.005890
# [g_f train] epoch 150/150  avg loss 2.011580
#
# === validating g_f (full grid, with visited/unvisited breakdown) ===
# [g_f eval] FULL GRID   mean KL = 0.6910  mean top-5 overlap = 0.653
# [g_f eval] visited-only    mean KL = 1.0938  mean top-5 overlap = 0.573  (n=7500)
# [g_f eval] unvisited-only  mean KL = 0.1315  mean top-5 overlap = 0.830  (n=3769)
# saved plot to gfunc_validation.png
#
# saved alpha_net.pt and gnet.pt
