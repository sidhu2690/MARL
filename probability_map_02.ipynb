# %% [markdown]
# <a href="https://colab.research.google.com/github/sidhu2690/MARL/blob/main/probability_map_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt


GRID = 12
N_ROBOTS = 10
ADV_FRAC = 0.5
STEPS = 150
EPSILON = 0.05
CONTRA_THRESH = 0.2
SEED = 40

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"[device] using {DEVICE}")

rng = np.random.default_rng(SEED)
torch.manual_seed(SEED)


def make_true_map(grid):
  xs, ys = np.meshgrid(np.arange(grid), np.arange(grid))
  field = np.zeros((grid, grid))
  for _ in range(5):
    cx, cy = rng.uniform(0, grid, 2)
    amp = rng.uniform(0.5, 1.0)
    sigma = rng.uniform(1.5, 3.5)
    field += amp * np.exp(-((xs - cx) ** 2 + (ys - cy) ** 2) / (2 * sigma ** 2))
  field = (field - field.min()) / (field.max() - field.min() + 1e-8)
  return field


def random_walk(grid, steps):
  pos = rng.integers(0, grid, size=2)
  cells = []
  for _ in range(steps):
    while True:
      move = rng.choice([-1, 0, 1], size=2)
      new_pos = np.clip(pos + move, 0, grid - 1)
      if not np.array_equal(new_pos, pos):
        break
    pos = new_pos
    cells.append(tuple(pos))
  return cells


def make_adv_mask(n_robots, adv_frac):
  n_adv = int(n_robots * adv_frac)
  mask = np.array([False] * (n_robots - n_adv) + [True] * n_adv)
  rng.shuffle(mask)
  return mask

def report_value(true_val, adversarial):
  if adversarial:
    val = true_val + rng.choice([-1, 1]) * rng.uniform(0.3, 0.6) + rng.normal(0, 0.1)
  else:
    val = true_val + rng.normal(0, 0.02)
  return float(np.clip(val, 0, 1))
# Part 1: alpha_net (unchanged, 3 features: c_norm, z, D)

class AlphaNet(nn.Module):
  def __init__(self):
    super().__init__()
    self.net = nn.Sequential(
      nn.Linear(3, 16), nn.ReLU(),
      nn.Linear(16, 8), nn.ReLU(),
      nn.Linear(8, 1), nn.Sigmoid(),
    )
  def forward(self, feats):
    return self.net(feats).squeeze(-1)



def train_alpha_net(episodes=400, lr=2e-3):
  alpha_net = AlphaNet().to(DEVICE)
  optimizer = torch.optim.Adam(alpha_net.parameters(), lr=lr)
  loss_history = []
  for ep in range(episodes):
    TRUE_MAP = make_true_map(GRID)
    is_adv = make_adv_mask(N_ROBOTS, ADV_FRAC)
    walks = [random_walk(GRID, STEPS) for _ in range(N_ROBOTS)]
    c = np.zeros(N_ROBOTS)
    D_sum = np.zeros(N_ROBOTS)
    D_n = np.zeros(N_ROBOTS)
    cell_reports = {}
    ep_loss = 0.0
    for t in range(STEPS):
      touched_cells = set()
      for i in range(N_ROBOTS):
        cell = walks[i][t]
        r_i = report_value(TRUE_MAP[cell], is_adv[i])
        others = cell_reports.get(cell, [])
        if others:
          residuals = [abs(r_i - r_j) for _, r_j in others]
          D_sum[i] += float(np.mean(residuals))
          D_n[i] += 1
          for j, r_j in others:
            if abs(r_i - r_j) > CONTRA_THRESH:
              c[i] += 1
              c[j] += 1
        cell_reports.setdefault(cell, []).append((i, r_i))
        touched_cells.add(cell)
      mu_c, sigma_c = c.mean(), c.std()
      z = (c - mu_c) / (sigma_c + EPSILON)
      D = np.divide(D_sum, D_n, out=np.zeros_like(D_sum), where=D_n > 0)
      c_norm = c / (t + 1)
      feats = torch.tensor(np.stack([c_norm, z, D], axis=1), dtype=torch.float32, device=DEVICE)
      alpha = alpha_net(feats)
      step_loss = 0.0
      for cell in touched_cells:
        reports = cell_reports[cell]
        idx = torch.tensor([r for r, _ in reports], device=DEVICE)
        vals = torch.tensor([v for _, v in reports], dtype=torch.float32, device=DEVICE)
        a = alpha[idx]
        M = (a * vals).sum() / (a.sum() + EPSILON)
        step_loss = step_loss + (TRUE_MAP[cell] - M) ** 2
      step_loss = step_loss / len(touched_cells)
      optimizer.zero_grad()
      step_loss.backward()
      optimizer.step()
      ep_loss += step_loss.item()
    loss_history.append(ep_loss / STEPS)
    if (ep + 1) % 100 == 0:
      print(f"[alpha_net] episode {ep+1}/{episodes}  avg loss {loss_history[-1]:.5f}")
  return alpha_net, loss_history
# Part 2: Produce (M_t, U_t, N_t) -> E_t training pairs  -- back to the ORIGINAL
# 3-channel state. No variance feature here; the only thing that changes in
# this version is the g_f architecture (CNN -> Transformer) and device support.

PRIOR = 0     # M_t(s) prior for never-observed cells

def error_scale_factor(U):
  return (2.0 * U + 1.0) / (U + 1.0) ** 2


def rollout_episode(alpha_net):
  TRUE_MAP = make_true_map(GRID)
  is_adv = make_adv_mask(N_ROBOTS, ADV_FRAC)
  walks = [random_walk(GRID, STEPS) for _ in range(N_ROBOTS)]
  c = np.zeros(N_ROBOTS)
  D_sum = np.zeros(N_ROBOTS)
  D_n = np.zeros(N_ROBOTS)
  cell_reports = {}
  xs, ys, es = [], [], []
  for t in range(STEPS):
    for i in range(N_ROBOTS):
      cell = walks[i][t]
      r_i = report_value(TRUE_MAP[cell], is_adv[i])
      others = cell_reports.get(cell, [])
      if others:
        residuals = [abs(r_i - r_j) for _, r_j in others]
        D_sum[i] += float(np.mean(residuals))
        D_n[i] += 1
        for j, r_j in others:
          if abs(r_i - r_j) > CONTRA_THRESH:
            c[i] += 1
            c[j] += 1
      cell_reports.setdefault(cell, []).append((i, r_i))
    mu_c, sigma_c = c.mean(), c.std()
    z = (c - mu_c) / (sigma_c + EPSILON)
    D = np.divide(D_sum, D_n, out=np.zeros_like(D_sum), where=D_n > 0)
    c_norm = c / (t + 1)
    feats = torch.tensor(np.stack([c_norm, z, D], axis=1), dtype=torch.float32, device=DEVICE)
    with torch.no_grad():
      alpha = alpha_net(feats).cpu().numpy()
    W_sum = np.zeros((GRID, GRID))
    A_sum = np.zeros((GRID, GRID))
    N_map = np.zeros((GRID, GRID))
    for cell, reports in cell_reports.items():
      idx = np.array([r for r, _ in reports])
      vals = np.array([v for _, v in reports])
      a = alpha[idx]
      W_sum[cell] = (a * vals).sum()
      A_sum[cell] = a.sum()
      N_map[cell] = len(reports)
    M_t = np.where(A_sum > 0, W_sum / np.maximum(A_sum, 1e-8), PRIOR)
    U_t = A_sum
    N_t = N_map

    e_t = TRUE_MAP - M_t
    err_old = e_t ** 2
    scale = error_scale_factor(U_t)
    Y_t = err_old * scale


    xs.append(np.stack([M_t, U_t, N_t]).astype(np.float32))
    ys.append(Y_t.astype(np.float32))        # oracle (for evaluation only)
    es.append(err_old.astype(np.float32))    # actual training target for g_f
  return xs, ys, es
# Part 3: g_f -- now a Transformer encoder instead of a CNN.
#
# Each of the 12x12=144 cells is treated as a token with 3 input features
# (M_t, U_t, N_t). A learned positional embedding gives each token its grid
# position (since the grid has no other notion of "where" a token is), then
# a few self-attention layers let every cell attend to every other cell
# directly -- full global receptive field in a single layer, rather than
# needing dilated convs to approximate it.

class GTransformer(nn.Module):
  def __init__(self, in_channels=3, grid=GRID, d_model=32, nhead=4,
               num_layers=2, dim_feedforward=64, dropout=0.0):
    super().__init__()
    self.grid = grid
    self.input_proj = nn.Linear(in_channels, d_model)
    self.pos_embed = nn.Parameter(torch.randn(1, grid * grid, d_model) * 0.02)
    encoder_layer = nn.TransformerEncoderLayer(
      d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward,
      dropout=dropout, batch_first=True,
    )
    self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
    self.output_proj = nn.Linear(d_model, 1)

  def forward(self, x):
    # x: (B, C, H, W)
    B, C, H, W = x.shape
    tokens = x.flatten(2).transpose(1, 2)          # (B, H*W, C)
    tokens = self.input_proj(tokens) + self.pos_embed
    out = self.encoder(tokens)                      # (B, H*W, d_model)
    out = self.output_proj(out).squeeze(-1)          # (B, H*W)
    return out.view(B, H, W)


GNet = GTransformer


def predict_R(gnet, X_t):
  with torch.no_grad():
    x = torch.tensor(X_t, dtype=torch.float32, device=DEVICE).unsqueeze(0)
    E_pred = gnet(x).squeeze(0).cpu().numpy()
  E_pred = np.clip(E_pred, 0, None)
  U_t = X_t[1]
  scale = error_scale_factor(U_t)
  return E_pred * scale


def build_dataset(alpha_net, episodes):
  X_all, E_all = [], []
  for ep in range(episodes):
    xs, ys, es = rollout_episode(alpha_net)
    X_all.extend(xs)
    E_all.extend(es)
    if (ep + 1) % 25 == 0:
      print(f"[g_f data] generated {ep+1}/{episodes} episodes "
            f"({len(X_all)} state samples so far)")
  X = torch.tensor(np.stack(X_all), dtype=torch.float32)
  E = torch.tensor(np.stack(E_all), dtype=torch.float32)
  return X, E


def train_gnet(X, E, max_epochs=150, lr=1e-3, batch_size=64,
               patience=8, min_delta=1e-4, balance_visited=True):
  gnet = GTransformer(in_channels=X.shape[1]).to(DEVICE)
  optimizer = torch.optim.Adam(gnet.parameters(), lr=lr)
  n = X.shape[0]
  loss_history = []
  best_loss = float("inf")
  bad_epochs = 0
  for epoch in range(max_epochs):
    perm = torch.randperm(n)
    epoch_loss = 0.0
    n_batches = 0
    for start in range(0, n, batch_size):
      idx = perm[start:start + batch_size]
      xb, eb = X[idx].to(DEVICE), E[idx].to(DEVICE)
      pred = gnet(xb)
      if balance_visited:
        visited = (xb[:, 2] > 0).float()
        n_vis = visited.sum().clamp(min=1.0)
        n_unvis = (1 - visited).sum().clamp(min=1.0)
        w = visited / n_vis + (1 - visited) / n_unvis
        loss = ((pred - eb) ** 2 * w).sum() / 2.0
      else:
        loss = ((pred - eb) ** 2).mean()
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      epoch_loss += loss.item()
      n_batches += 1
    avg_loss = epoch_loss / n_batches
    loss_history.append(avg_loss)
    print(f"[g_f train] epoch {epoch+1}/{max_epochs}  avg loss {avg_loss:.6f}")
    if best_loss - avg_loss > min_delta:
      best_loss = avg_loss
      bad_epochs = 0
    else:
      bad_epochs += 1
      if bad_epochs >= patience:
        print(f"[g_f train] plateaued at epoch {epoch+1}, stopping early")
        break
  return gnet, loss_history
# Part 4: validation (unchanged)

def normalize_nonneg(y):
  y = np.clip(y, 0, None)
  s = y.sum()
  if s <= 1e-12:
    return np.full_like(y, 1.0 / y.size)
  return y / s

def kl_divergence(p_true, p_pred, eps=1e-8):
  p_true = np.clip(p_true, eps, None)
  p_pred = np.clip(p_pred, eps, None)
  return float(np.sum(p_true * np.log(p_true / p_pred)))

def topk_overlap(y_true_flat, r_pred_flat, k=5):
  k = min(k, y_true_flat.size)
  true_top = set(np.argsort(y_true_flat)[-k:])
  pred_top = set(np.argsort(r_pred_flat)[-k:])
  return len(true_top & pred_top) / k

def evaluate(gnet, alpha_net, episodes=20, k=30):
  kls, overlaps = [], []
  kls_vis, overlaps_vis = [], []
  kls_unvis, overlaps_unvis = [], []
  sample_X, sample_Y, sample_R = None, None, None
  for ep in range(episodes):
    xs, ys, _es = rollout_episode(alpha_net)   # ys = oracle Y_t, for eval only
    for X_t, Y_t in zip(xs, ys):
      R_t = predict_R(gnet, X_t)
      N_t = X_t[2]
      p_true = normalize_nonneg(Y_t)
      p_pred = normalize_nonneg(R_t)
      kls.append(kl_divergence(p_true, p_pred))
      overlaps.append(topk_overlap(Y_t.reshape(-1), R_t.reshape(-1), k=k))
      vis_mask = N_t > 0
      if vis_mask.sum() >= k:
        yv, rv = Y_t[vis_mask], R_t[vis_mask]
        kls_vis.append(kl_divergence(normalize_nonneg(yv), normalize_nonneg(rv)))
        overlaps_vis.append(topk_overlap(yv, rv, k=k))
      unvis_mask = N_t == 0
      if unvis_mask.sum() >= k:
        yu, ru = Y_t[unvis_mask], R_t[unvis_mask]
        kls_unvis.append(kl_divergence(normalize_nonneg(yu), normalize_nonneg(ru)))
        overlaps_unvis.append(topk_overlap(yu, ru, k=k))
      if sample_X is None and Y_t.sum() > 1e-6:
        sample_X, sample_Y, sample_R = X_t, Y_t, R_t
  print(f"[g_f eval] FULL GRID   mean KL = {np.mean(kls):.4f}  "
        f"mean top-{k} overlap = {np.mean(overlaps):.3f}")
  print(f"[g_f eval] visited-only    mean KL = {np.mean(kls_vis):.4f}  "
        f"mean top-{k} overlap = {np.mean(overlaps_vis):.3f}  (n={len(kls_vis)})")
  print(f"[g_f eval] unvisited-only  mean KL = {np.mean(kls_unvis):.4f}  "
        f"mean top-{k} overlap = {np.mean(overlaps_unvis):.3f}  (n={len(kls_unvis)})")
  return kls, overlaps, (sample_X, sample_Y, sample_R)


def plot_validation(kls, overlaps, sample, k=30):
  sample_X, sample_Y, sample_R = sample
  p_true = normalize_nonneg(sample_Y)
  p_pred = normalize_nonneg(sample_R)
  fig, axes = plt.subplots(2, 3, figsize=(13, 8))
  axes[0, 0].imshow(sample_X[0], cmap="viridis")
  axes[0, 0].set_title("M_t (trust-weighted estimate)")
  axes[0, 1].imshow(p_true, cmap="magma")
  axes[0, 1].set_title("P_true(s)  (from oracle Y_t, full grid)")
  axes[0, 2].imshow(p_pred, cmap="magma")
  axes[0, 2].set_title("P_pred(s)  (g_f error x analytic scale, full grid)")
  axes[1, 0].hist(kls, bins=30)
  axes[1, 0].set_title("KL(P_true || P_pred) across test states")
  axes[1, 0].set_xlabel("KL divergence")
  axes[1, 1].hist(overlaps, bins=np.linspace(0, 1, 11))
  axes[1, 1].set_title(f"Top-{k} cell overlap across test states")
  axes[1, 1].set_xlabel("fraction overlap")
  axes[1, 2].scatter(sample_Y.reshape(-1), sample_R.reshape(-1), s=10, alpha=0.6)
  axes[1, 2].set_xlabel("oracle Y_t(s)")
  axes[1, 2].set_ylabel("predicted R_t(s)")
  axes[1, 2].set_title("Y_t vs R_t (one state, all cells)")
  for ax in axes[0]:
    plt.colorbar(ax.images[0], ax=ax, fraction=0.046)
  plt.tight_layout()
  plt.savefig("gfunc_validation_transformer.png", dpi=130)
  print("saved plot to gfunc_validation_transformer.png")


if __name__ == "__main__":
  ALPHA_EPISODES = 500
  G_DATA_EPISODES = 5000
  G_MAX_EPOCHS = 30
  EVAL_EPISODES = 100

  print("=== training alpha_net ===")
  alpha_net, alpha_loss = train_alpha_net(episodes=ALPHA_EPISODES)

  print("\n=== generating g_f training data (3 channels: M_t, U_t, N_t) ===")
  X, E = build_dataset(alpha_net, episodes=G_DATA_EPISODES)
  print("dataset:", X.shape, E.shape, " E (error-energy) stats:",
        float(E.min()), float(E.max()), float(E.mean()))

  print("\n=== training g_f (Transformer, predicts error energy only, full grid, "
        "visited/unvisited loss-balanced) ===")
  gnet, g_loss = train_gnet(X, E, max_epochs=G_MAX_EPOCHS)

  print("\n=== validating g_f (Y_t reconstructed as e_pred^2 * scale(U), "
        "with visited/unvisited breakdown) ===")
  kls, overlaps, sample = evaluate(gnet, alpha_net, episodes=EVAL_EPISODES)
  plot_validation(kls, overlaps, sample)

  torch.save(alpha_net.state_dict(), "alpha_net.pt")
  torch.save(gnet.state_dict(), "gnet_transformer.pt")
  print("\nsaved alpha_net.pt and gnet_transformer.pt")
# Out:
# [device] using cuda
# === training alpha_net ===
# [alpha_net] episode 100/500  avg loss 0.01075
# [alpha_net] episode 200/500  avg loss 0.01142
# [alpha_net] episode 300/500  avg loss 0.01384
# [alpha_net] episode 400/500  avg loss 0.01112
# [alpha_net] episode 500/500  avg loss 0.01063
#
# === generating g_f training data (3 channels: M_t, U_t, N_t) ===
# [g_f data] generated 25/5000 episodes (3750 state samples so far)
# [g_f data] generated 50/5000 episodes (7500 state samples so far)
# [g_f data] generated 75/5000 episodes (11250 state samples so far)
# [g_f data] generated 100/5000 episodes (15000 state samples so far)
# [g_f data] generated 125/5000 episodes (18750 state samples so far)
# [g_f data] generated 150/5000 episodes (22500 state samples so far)
# [g_f data] generated 175/5000 episodes (26250 state samples so far)
# [g_f data] generated 200/5000 episodes (30000 state samples so far)
# [g_f data] generated 225/5000 episodes (33750 state samples so far)
# [g_f data] generated 250/5000 episodes (37500 state samples so far)
# [g_f data] generated 275/5000 episodes (41250 state samples so far)
# [g_f data] generated 300/5000 episodes (45000 state samples so far)
# [g_f data] generated 325/5000 episodes (48750 state samples so far)
# [g_f data] generated 350/5000 episodes (52500 state samples so far)
# [g_f data] generated 375/5000 episodes (56250 state samples so far)
# [g_f data] generated 400/5000 episodes (60000 state samples so far)
# [g_f data] generated 425/5000 episodes (63750 state samples so far)
# [g_f data] generated 450/5000 episodes (67500 state samples so far)
# [g_f data] generated 475/5000 episodes (71250 state samples so far)
# [g_f data] generated 500/5000 episodes (75000 state samples so far)
# [g_f data] generated 525/5000 episodes (78750 state samples so far)
# [g_f data] generated 550/5000 episodes (82500 state samples so far)
# [g_f data] generated 575/5000 episodes (86250 state samples so far)
# [g_f data] generated 600/5000 episodes (90000 state samples so far)
# [g_f data] generated 625/5000 episodes (93750 state samples so far)
# [g_f data] generated 650/5000 episodes (97500 state samples so far)
# [g_f data] generated 675/5000 episodes (101250 state samples so far)
# [g_f data] generated 700/5000 episodes (105000 state samples so far)
# [g_f data] generated 725/5000 episodes (108750 state samples so far)
# [g_f data] generated 750/5000 episodes (112500 state samples so far)
# [g_f data] generated 775/5000 episodes (116250 state samples so far)
# [g_f data] generated 800/5000 episodes (120000 state samples so far)
# [g_f data] generated 825/5000 episodes (123750 state samples so far)
# [g_f data] generated 850/5000 episodes (127500 state samples so far)
# [g_f data] generated 875/5000 episodes (131250 state samples so far)
# [g_f data] generated 900/5000 episodes (135000 state samples so far)
# [g_f data] generated 925/5000 episodes (138750 state samples so far)
# [g_f data] generated 950/5000 episodes (142500 state samples so far)
# [g_f data] generated 975/5000 episodes (146250 state samples so far)
# [g_f data] generated 1000/5000 episodes (150000 state samples so far)
# [g_f data] generated 1025/5000 episodes (153750 state samples so far)
# [g_f data] generated 1050/5000 episodes (157500 state samples so far)
# [g_f data] generated 1075/5000 episodes (161250 state samples so far)
# [g_f data] generated 1100/5000 episodes (165000 state samples so far)
# [g_f data] generated 1125/5000 episodes (168750 state samples so far)
# [g_f data] generated 1150/5000 episodes (172500 state samples so far)
# [g_f data] generated 1175/5000 episodes (176250 state samples so far)
# [g_f data] generated 1200/5000 episodes (180000 state samples so far)
# [g_f data] generated 1225/5000 episodes (183750 state samples so far)
# [g_f data] generated 1250/5000 episodes (187500 state samples so far)
# [g_f data] generated 1275/5000 episodes (191250 state samples so far)
# [g_f data] generated 1300/5000 episodes (195000 state samples so far)
# [g_f data] generated 1325/5000 episodes (198750 state samples so far)
# [g_f data] generated 1350/5000 episodes (202500 state samples so far)
# [g_f data] generated 1375/5000 episodes (206250 state samples so far)
# [g_f data] generated 1400/5000 episodes (210000 state samples so far)
# [g_f data] generated 1425/5000 episodes (213750 state samples so far)
# [g_f data] generated 1450/5000 episodes (217500 state samples so far)
# [g_f data] generated 1475/5000 episodes (221250 state samples so far)
# [g_f data] generated 1500/5000 episodes (225000 state samples so far)
# [g_f data] generated 1525/5000 episodes (228750 state samples so far)
# [g_f data] generated 1550/5000 episodes (232500 state samples so far)
# [g_f data] generated 1575/5000 episodes (236250 state samples so far)
# [g_f data] generated 1600/5000 episodes (240000 state samples so far)
# [g_f data] generated 1625/5000 episodes (243750 state samples so far)
# [g_f data] generated 1650/5000 episodes (247500 state samples so far)
# [g_f data] generated 1675/5000 episodes (251250 state samples so far)
# [g_f data] generated 1700/5000 episodes (255000 state samples so far)
# [g_f data] generated 1725/5000 episodes (258750 state samples so far)
# [g_f data] generated 1750/5000 episodes (262500 state samples so far)
# [g_f data] generated 1775/5000 episodes (266250 state samples so far)
# [g_f data] generated 1800/5000 episodes (270000 state samples so far)
# [g_f data] generated 1825/5000 episodes (273750 state samples so far)
# [g_f data] generated 1850/5000 episodes (277500 state samples so far)
# [g_f data] generated 1875/5000 episodes (281250 state samples so far)
# [g_f data] generated 1900/5000 episodes (285000 state samples so far)
# [g_f data] generated 1925/5000 episodes (288750 state samples so far)
# [g_f data] generated 1950/5000 episodes (292500 state samples so far)
# [g_f data] generated 1975/5000 episodes (296250 state samples so far)
# [g_f data] generated 2000/5000 episodes (300000 state samples so far)
# [g_f data] generated 2025/5000 episodes (303750 state samples so far)
# [g_f data] generated 2050/5000 episodes (307500 state samples so far)
# [g_f data] generated 2075/5000 episodes (311250 state samples so far)
# [g_f data] generated 2100/5000 episodes (315000 state samples so far)
# [g_f data] generated 2125/5000 episodes (318750 state samples so far)
# [g_f data] generated 2150/5000 episodes (322500 state samples so far)
# [g_f data] generated 2175/5000 episodes (326250 state samples so far)
# [g_f data] generated 2200/5000 episodes (330000 state samples so far)
# [g_f data] generated 2225/5000 episodes (333750 state samples so far)
# [g_f data] generated 2250/5000 episodes (337500 state samples so far)
# [g_f data] generated 2275/5000 episodes (341250 state samples so far)
# [g_f data] generated 2300/5000 episodes (345000 state samples so far)
# [g_f data] generated 2325/5000 episodes (348750 state samples so far)
# [g_f data] generated 2350/5000 episodes (352500 state samples so far)
# [g_f data] generated 2375/5000 episodes (356250 state samples so far)
# [g_f data] generated 2400/5000 episodes (360000 state samples so far)
# [g_f data] generated 2425/5000 episodes (363750 state samples so far)
# [g_f data] generated 2450/5000 episodes (367500 state samples so far)
# [g_f data] generated 2475/5000 episodes (371250 state samples so far)
# [g_f data] generated 2500/5000 episodes (375000 state samples so far)
# [g_f data] generated 2525/5000 episodes (378750 state samples so far)
# [g_f data] generated 2550/5000 episodes (382500 state samples so far)
# [g_f data] generated 2575/5000 episodes (386250 state samples so far)
# [g_f data] generated 2600/5000 episodes (390000 state samples so far)
# [g_f data] generated 2625/5000 episodes (393750 state samples so far)
# [g_f data] generated 2650/5000 episodes (397500 state samples so far)
# [g_f data] generated 2675/5000 episodes (401250 state samples so far)
# [g_f data] generated 2700/5000 episodes (405000 state samples so far)
# [g_f data] generated 2725/5000 episodes (408750 state samples so far)
# [g_f data] generated 2750/5000 episodes (412500 state samples so far)
# [g_f data] generated 2775/5000 episodes (416250 state samples so far)
# [g_f data] generated 2800/5000 episodes (420000 state samples so far)
# [g_f data] generated 2825/5000 episodes (423750 state samples so far)
# [g_f data] generated 2850/5000 episodes (427500 state samples so far)
# [g_f data] generated 2875/5000 episodes (431250 state samples so far)
# [g_f data] generated 2900/5000 episodes (435000 state samples so far)
# [g_f data] generated 2925/5000 episodes (438750 state samples so far)
# [g_f data] generated 2950/5000 episodes (442500 state samples so far)
# [g_f data] generated 2975/5000 episodes (446250 state samples so far)
# [g_f data] generated 3000/5000 episodes (450000 state samples so far)
# [g_f data] generated 3025/5000 episodes (453750 state samples so far)
# [g_f data] generated 3050/5000 episodes (457500 state samples so far)
# [g_f data] generated 3075/5000 episodes (461250 state samples so far)
# [g_f data] generated 3100/5000 episodes (465000 state samples so far)
# [g_f data] generated 3125/5000 episodes (468750 state samples so far)
# [g_f data] generated 3150/5000 episodes (472500 state samples so far)
# [g_f data] generated 3175/5000 episodes (476250 state samples so far)
# [g_f data] generated 3200/5000 episodes (480000 state samples so far)
# [g_f data] generated 3225/5000 episodes (483750 state samples so far)
# [g_f data] generated 3250/5000 episodes (487500 state samples so far)
# [g_f data] generated 3275/5000 episodes (491250 state samples so far)
# [g_f data] generated 3300/5000 episodes (495000 state samples so far)
# [g_f data] generated 3325/5000 episodes (498750 state samples so far)
# [g_f data] generated 3350/5000 episodes (502500 state samples so far)
# [g_f data] generated 3375/5000 episodes (506250 state samples so far)
# [g_f data] generated 3400/5000 episodes (510000 state samples so far)
# [g_f data] generated 3425/5000 episodes (513750 state samples so far)
# [g_f data] generated 3450/5000 episodes (517500 state samples so far)
# [g_f data] generated 3475/5000 episodes (521250 state samples so far)
# [g_f data] generated 3500/5000 episodes (525000 state samples so far)
# [g_f data] generated 3525/5000 episodes (528750 state samples so far)
# [g_f data] generated 3550/5000 episodes (532500 state samples so far)
# [g_f data] generated 3575/5000 episodes (536250 state samples so far)
# [g_f data] generated 3600/5000 episodes (540000 state samples so far)
# [g_f data] generated 3625/5000 episodes (543750 state samples so far)
# [g_f data] generated 3650/5000 episodes (547500 state samples so far)
# [g_f data] generated 3675/5000 episodes (551250 state samples so far)
# [g_f data] generated 3700/5000 episodes (555000 state samples so far)
# [g_f data] generated 3725/5000 episodes (558750 state samples so far)
# [g_f data] generated 3750/5000 episodes (562500 state samples so far)
# [g_f data] generated 3775/5000 episodes (566250 state samples so far)
# [g_f data] generated 3800/5000 episodes (570000 state samples so far)
# [g_f data] generated 3825/5000 episodes (573750 state samples so far)
# [g_f data] generated 3850/5000 episodes (577500 state samples so far)
# [g_f data] generated 3875/5000 episodes (581250 state samples so far)
# [g_f data] generated 3900/5000 episodes (585000 state samples so far)
# [g_f data] generated 3925/5000 episodes (588750 state samples so far)
# [g_f data] generated 3950/5000 episodes (592500 state samples so far)
# [g_f data] generated 3975/5000 episodes (596250 state samples so far)
# [g_f data] generated 4000/5000 episodes (600000 state samples so far)
# [g_f data] generated 4025/5000 episodes (603750 state samples so far)
# [g_f data] generated 4050/5000 episodes (607500 state samples so far)
# [g_f data] generated 4075/5000 episodes (611250 state samples so far)
# [g_f data] generated 4100/5000 episodes (615000 state samples so far)
# [g_f data] generated 4125/5000 episodes (618750 state samples so far)
# [g_f data] generated 4150/5000 episodes (622500 state samples so far)
# [g_f data] generated 4175/5000 episodes (626250 state samples so far)
# [g_f data] generated 4200/5000 episodes (630000 state samples so far)
# [g_f data] generated 4225/5000 episodes (633750 state samples so far)
# [g_f data] generated 4250/5000 episodes (637500 state samples so far)
# [g_f data] generated 4275/5000 episodes (641250 state samples so far)
# [g_f data] generated 4300/5000 episodes (645000 state samples so far)
# [g_f data] generated 4325/5000 episodes (648750 state samples so far)
# [g_f data] generated 4350/5000 episodes (652500 state samples so far)
# [g_f data] generated 4375/5000 episodes (656250 state samples so far)
# [g_f data] generated 4400/5000 episodes (660000 state samples so far)
# [g_f data] generated 4425/5000 episodes (663750 state samples so far)
# [g_f data] generated 4450/5000 episodes (667500 state samples so far)
# [g_f data] generated 4475/5000 episodes (671250 state samples so far)
# [g_f data] generated 4500/5000 episodes (675000 state samples so far)
# [g_f data] generated 4525/5000 episodes (678750 state samples so far)
# [g_f data] generated 4550/5000 episodes (682500 state samples so far)
# [g_f data] generated 4575/5000 episodes (686250 state samples so far)
# [g_f data] generated 4600/5000 episodes (690000 state samples so far)
# [g_f data] generated 4625/5000 episodes (693750 state samples so far)
# [g_f data] generated 4650/5000 episodes (697500 state samples so far)
# [g_f data] generated 4675/5000 episodes (701250 state samples so far)
# [g_f data] generated 4700/5000 episodes (705000 state samples so far)
# [g_f data] generated 4725/5000 episodes (708750 state samples so far)
# [g_f data] generated 4750/5000 episodes (712500 state samples so far)
# [g_f data] generated 4775/5000 episodes (716250 state samples so far)
# [g_f data] generated 4800/5000 episodes (720000 state samples so far)
# [g_f data] generated 4825/5000 episodes (723750 state samples so far)
# [g_f data] generated 4850/5000 episodes (727500 state samples so far)
# [g_f data] generated 4875/5000 episodes (731250 state samples so far)
# [g_f data] generated 4900/5000 episodes (735000 state samples so far)
# [g_f data] generated 4925/5000 episodes (738750 state samples so far)
# [g_f data] generated 4950/5000 episodes (742500 state samples so far)
# [g_f data] generated 4975/5000 episodes (746250 state samples so far)
# [g_f data] generated 5000/5000 episodes (750000 state samples so far)
# dataset: torch.Size([750000, 3, 12, 12]) torch.Size([750000, 12, 12])  E (error-energy) stats: 0.0 1.0 0.04770595207810402
#
# === training g_f (Transformer, predicts error energy only, full grid, visited/unvisited loss-balanced) ===
# [g_f train] epoch 1/30  avg loss 0.017337
# [g_f train] epoch 2/30  avg loss 0.009137
# [g_f train] epoch 3/30  avg loss 0.008161
# [g_f train] epoch 4/30  avg loss 0.007634
# [g_f train] epoch 5/30  avg loss 0.007299
# [g_f train] epoch 6/30  avg loss 0.007047
# [g_f train] epoch 7/30  avg loss 0.006832
# [g_f train] epoch 8/30  avg loss 0.006659
# [g_f train] epoch 9/30  avg loss 0.006535
# [g_f train] epoch 10/30  avg loss 0.006438
# [g_f train] epoch 11/30  avg loss 0.006365
# [g_f train] epoch 12/30  avg loss 0.006293
# [g_f train] epoch 13/30  avg loss 0.006225
# [g_f train] epoch 14/30  avg loss 0.006170
# [g_f train] epoch 15/30  avg loss 0.006106
# [g_f train] epoch 16/30  avg loss 0.006059
# [g_f train] epoch 17/30  avg loss 0.006023
# [g_f train] epoch 18/30  avg loss 0.005987
# [g_f train] epoch 19/30  avg loss 0.005946
# [g_f train] epoch 20/30  avg loss 0.005921
# [g_f train] epoch 21/30  avg loss 0.005887
# [g_f train] epoch 22/30  avg loss 0.005856
# [g_f train] epoch 23/30  avg loss 0.005835
# [g_f train] epoch 24/30  avg loss 0.005811
# [g_f train] epoch 25/30  avg loss 0.005788
# [g_f train] epoch 26/30  avg loss 0.005763
# [g_f train] epoch 27/30  avg loss 0.005753
# [g_f train] epoch 28/30  avg loss 0.005720
# [g_f train] epoch 29/30  avg loss 0.005716
# [g_f train] epoch 30/30  avg loss 0.005697
#
# === validating g_f (Y_t reconstructed as e_pred^2 * scale(U), with visited/unvisited breakdown) ===
# [g_f eval] FULL GRID   mean KL = 0.1681  mean top-30 overlap = 0.781
# [g_f eval] visited-only    mean KL = 0.2188  mean top-30 overlap = 0.766  (n=14682)
# [g_f eval] unvisited-only  mean KL = 0.1229  mean top-30 overlap = 0.849  (n=3561)
# saved plot to gfunc_validation_transformer.png
#
# saved alpha_net.pt and gnet_transformer.pt
